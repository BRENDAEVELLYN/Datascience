# %% [markdown]
# # Imobiliária Aluga Rápido

# %% [markdown]
# #### Importando Dados

# %%
import pandas as pd

# %%
url = "dataset/aluguel.csv"
pd.read_csv(url)
# Out:
#       Tipo;Bairro;Quartos;Vagas;Suites;Area;Valor;Condominio;IPTU
# 0              Quitinete;Copacabana;1;0;0;40;1700;500;60
# 1                  Casa;Jardim Botânico;2;0;1;100;7000;;
# 2      Conjunto Comercial/Sala;Barra da Tijuca;0;4;0;...
# 3                 Apartamento;Centro;1;0;0;15;800;390;20
# 4             Apartamento;Higienópolis;1;0;0;48;800;230;
# ...                                                  ...
# 32955               Quitinete;Centro;0;0;0;27;800;350;25
# 32956       Apartamento;Jacarepaguá;3;1;2;78;1800;800;40
# 32957  Apartamento;São Francisco Xavier;2;1;0;48;1400...
# 32958              Apartamento;Leblon;2;0;0;70;3000;760;
# 32959  Conjunto Comercial/Sala;Centro;0;0;0;250;6500;...
#
# [32960 rows x 1 columns]

# %%
print(type(url))
# Out:
# <class 'str'>

# %% [markdown]
# # comma-separated values (csv)

# %% [markdown]
# As vezes não vem separado por vírgula, como nosso exemplo, veio separado por ponto e vírgula.

# %%
pd.read_csv(url,sep=";")
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# ...

# %% [markdown]
# ## Criando variáveis

# %%
dados = pd.read_csv(url,sep=";")
dados
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# ...

# %% [markdown]
# # Visualizar apenas algumas linhas

# %% [markdown]
# Utiliza-se o método head (readi)

# %%
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN

# %% [markdown]
# ##### A função head() retonar as cinco primeiras linhas. Caso necessite mostrar mais é só passar o número de linha desejada.

# %%
dados.head(15)
# Out:
#                        Tipo               Bairro  Quartos  Vagas  Suites  \
# 0                 Quitinete           Copacabana        1      0       0
# 1                      Casa      Jardim Botânico        2      0       1
# 2   Conjunto Comercial/Sala      Barra da Tijuca        0      4       0
# 3               Apartamento               Centro        1      0       0
# 4               Apartamento         Higienópolis        1      0       0
# 5               Apartamento         Vista Alegre        3      1       0
# 6               Apartamento             Cachambi        2      0       0
# 7        Casa de Condomínio      Barra da Tijuca        5      4       5
# 8        Casa de Condomínio                Ramos        2      2       0
# 9   Conjunto Comercial/Sala               Centro        0      3       0
# 10              Apartamento               Centro        1      0       0
# 11              Apartamento               Grajaú        2      1       0
# ...

# %% [markdown]
# ##### Temos outro método, que mostra das últimas linhas

# %%
dados.tail()
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# 32955    27   800.0       350.0    25.0
# 32956    78  1800.0       800.0    40.0
# 32957    48  1400.0       509.0    37.0
# 32958    70  3000.0       760.0     NaN
# 32959   250  6500.0      4206.0  1109.0

# %%
dados.tail(20)
# Out:
#                           Tipo                    Bairro  Quartos  Vagas  \
# 32940              Apartamento           Barra da Tijuca        2      1
# 32941              Apartamento           Barra da Tijuca        3      2
# 32942  Conjunto Comercial/Sala           Barra da Tijuca        0      1
# 32943              Apartamento           Barra da Tijuca        3      2
# 32944              Apartamento  Recreio dos Bandeirantes        3      2
# 32945                Quitinete                Copacabana        1      0
# 32946  Conjunto Comercial/Sala                    Centro        0      0
# 32947              Apartamento                    Leblon        3      0
# 32948  Conjunto Comercial/Sala                    Centro        0      0
# 32949              Apartamento                   Ipanema        3      1
# 32950              Apartamento                    Tijuca        1      0
# 32951              Apartamento            Vila Valqueire        2      0
# ...

# %%
"""
    Mostrando o tipo da minha variável 
"""
type(dados)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# É muito importante aprender essa estrutura "DataFrame". A tabela que foi gerada é uma estrutura de dados chamada DataFrame. Vamos utiliza-lá do inicio ao fim do nosso curso.

# %% [markdown]
# Finalizamos nossa tarefa no Trello!

# %% [markdown]
# # Exercício

# %% [markdown]
# ### Questões estilo Cebraspe sobre Pandas
#
# 1. **(Cebraspe - Adaptada)** A função `read_csv()` do Pandas é utilizada exclusivamente para ler arquivos no formato CSV sem a possibilidade de personalização de parâmetros adicionais.
#    - [ ] Verdadeiro
#    - [ ] Falso
#
# 2. **(Cebraspe - Adaptada)** A função `read_excel()` do Pandas é capaz de criar um DataFrame a partir de arquivos no formato XLSX, mas não suporta arquivos no formato XLS.
#    - [ ] Verdadeiro
#    - [ ] Falso
#
# 3. **(Cebraspe - Adaptada)** A função `read_json()` do Pandas é voltada exclusivamente para ler arquivos JSON estruturados com arrays de objetos JavaScript.
#    - [ ] Verdadeiro
#    - [ ] Falso
#
# 4. **(Cebraspe - Adaptada)** A função `read_html()` do Pandas é utilizada para ler qualquer tipo de conteúdo HTML de uma página da web e não se limita apenas a tabelas estruturadas.
#    - [ ] Verdadeiro
#    - [ ] Falso
#
# 5. **(Cebraspe - Adaptada)** A função `read_sql()` do Pandas permite ler dados de bancos de dados relacionais como MySQL e PostgreSQL, mas não suporta a importação de dados de SQL Server.
#    - [ ] Verdadeiro
#    - [ ] Falso
#
# ### Gabarito Comentado
#
# 1. **Falso**
#    - A função `read_csv()` permite passar diversos parâmetros para personalizar a leitura do CSV, como delimitador, cabeçalho, tipo de encoding, entre outros.
#
# 2. **Falso**
#    - A função `read_excel()` suporta tanto arquivos no formato XLS quanto XLSX para criar DataFrames.
#
# 3. **Verdadeiro**
#    - A função `read_json()` é utilizada especificamente para ler arquivos JSON que contenham dados no formato de objeto JavaScript.
#
# 4. **Verdadeiro**
#    - A função `read_html()` pode ser utilizada para ler tabelas HTML, mas não se limita a elas; pode extrair qualquer conteúdo HTML estruturado.
#
# 5. **Falso**
#    - A função `read_sql()` do Pandas é capaz de ler dados de bancos de dados como MySQL, PostgreSQL e SQL Server, permitindo ajustar parâmetros como a consulta SQL e o tipo de dados das colunas.
